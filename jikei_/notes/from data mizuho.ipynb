# %%
import numpy as np
import scipy as sp
import pandas as pd
from pandas import DataFrame, Series

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
df_historcal = pd.read_csv("../code/momo.csv")

# %%
df_historcal
# Out:
#     Unnamed: 0     USD     GBP     EUR    CAD     CHF    SEK    DKK    NOK  \
# 0    2002/4/30  131.15  189.01  115.97  82.83   79.13  12.73  15.61  15.20
# 1    2002/5/31  126.44  184.56  115.88  81.58   79.60  12.57  15.59  15.43
# 2    2002/6/28  123.53  183.00  117.83  80.64   80.09  12.94  15.86  15.92
# 3    2002/7/31  118.05  183.64  117.23  76.52   80.16  12.67  15.79  15.83
# 4    2002/8/30  119.08  183.14  116.45  75.85   79.60  12.59  15.69  15.68
# ..         ...     ...     ...     ...    ...     ...    ...    ...    ...
# 214  2020/2/28  109.99  142.71  119.99  82.82  112.68  11.36  16.06  11.85
# 215  2020/3/31  107.54  133.35  119.14  77.33  112.37  10.98  15.95  10.61
# 216  2020/4/30  107.96  133.97  117.37  76.74  111.26  10.76  15.73  10.35
# 217  2020/5/29  107.35  131.83  116.99  76.89  110.64  11.04  15.69  10.65
# 218  2020/6/30  107.55  134.74  121.05  79.33  112.94  11.55  16.24  11.29
#
#        AUD  ...    HUF    CZK    PLN   RUB    TRY  IDR(100).1  CNY.1  MYR.1  \
# 0    70.24  ...  *****  *****  *****   NaN    NaN        1.39  15.84  *****
# 1    69.58  ...  *****  *****  *****   NaN    NaN        1.41  15.28  *****
# 2    70.29  ...  *****  *****  *****   NaN    NaN        1.44  14.93  *****
# 3    65.42  ...  *****  *****  *****   NaN    NaN        1.34  14.26  *****
# 4    64.47  ...  *****  *****  *****   NaN    NaN        1.35  14.39  *****
# ..     ...  ...    ...    ...    ...   ...    ...         ...    ...    ...
# 214  73.41  ...   0.36   4.79  28.06  1.72  18.17        0.80  *****  26.47
# 215  67.06  ...   0.35   4.51  26.93  1.46  17.02        0.71  *****  25.08
# 216  67.82  ...   0.33    4.3  25.83  1.44  15.80        0.68  *****  24.84
# 217  70.03  ...   0.33   4.29  25.83  1.48  15.54        0.72  *****  24.74
# 218  74.08  ...   0.35   4.54  27.26  1.55  15.78        0.76  *****  25.17
#
#      KRW(100).1   TWD
# 0          9.99  3.77
# 1         10.10  3.68
# 2         10.20  3.66
# 3          9.98  3.56
# 4          9.97  3.53
# ..          ...   ...
# 214        9.21  3.65
# 215        8.83  3.57
# 216        8.82  3.59
# 217        8.74  3.59
# 218        8.90  3.63
#
# [219 rows x 37 columns]

# %%
df_historcal.USD.plot()

# %%
df_historcal.USD.rolling(24).mean().plot()
